# %% [markdown]
# <a href="https://colab.research.google.com/github/luandmsc/Tecnicas-de-Programacao/blob/main/Eng_Soft_6nov_Luan.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Operadores

# %%
2**3
# Out:
# 8

# %%
23//7
# Out:
# 3

# %%
23%7
# Out:
# 2

# %%
5+5*5/5
# Out:
# 10.0

# %%
4**(4/2)+7
# Out:
# 23.0

# %%
#Tarefa 1

a=int(input("Informe o número:  "))
b=int(input("Informe o número:  "))
print("O resultado é ",
      a+b)
# Out:
# Informe o número:  7
# Informe o número:  8
# O resultado é  15

# %%
#Tarefa 2
'''
Faça um programa que leia a nota que um
aluno tirou em P1(Prova 1) e P2(Prova 2).
'''
P1=float(input("Informe a nota da P1:  "))
P2=float(input("Informe a nota da P2:  "))
media_aritmetica=(P1+P2)//2
print("A média aritmética é ", media_aritmetica)
# Out:
# Informe a nota da P1:  6
# Informe a nota da P2:  7
# A média aritmética é  6.5

# %%
#Tarefa 3
'''
Leia um nome armazenado em uma variável
e imprima:
'''
nome=input("Informe o nome:  ")
print("Olá ", nome)
# Out:
# Informe o nome:  luan
# Olá  luan

# %%
#Tarefa 4
'''
Solicite que o usuário digite seu nome.
Solicite que o usuários digite seu ano de nascimento (formato AAAA).
Exiba na tela:
nome_usuario nasceu em ano_nascimento!
(nome_usuario e ano_nascimento
são as variáveis)
'''
nome=input("Informe o nome:  ")
ano_nascimento=int(input("Informe o ano de nascimento:  "))
print(nome, "nasceu em ", ano_nascimento)
# Out:
# Informe o nome:  luan
# Informe o ano de nascimento:  2007
# luan nasceu em  2007

# %%
#Tarefa 5
'''
Solicite que o usuário digite seu nome e sua idade.
Imprima “Olá, nome! Você tem idade anos?”
Imprima o ano de nascimento da pessoa (ignore meses e dias)
Imprima o nome da pessoa idade vezes (João tem 18, imprime JoãoJoão...)
'''
nome=input("Informe o nome:  ")
idade=int(input("Informe a idade:  "))
ano_nascimento=int(input("Informe o ano de nascimento:  "))
print("Olá ", nome, "Você tem ", idade, "anos")
print("Você nasceu em ", ano_nascimento)
# Out:
# Informe o nome:  luan
# Informe a idade:  18
# Informe o ano de nascimento:  2007
# Olá  luan Você tem  18 anos
# Você nasceu em  2007

# %%
#Tarefa 6
n1 = float(input("informe a primeira nota: "))
n2 = float(input("informe a segunda nota: "))
n3 = float(input("informe a terceira nota"))
media = (n1+n2+n3)/3
print("media: ", media)
# Out:
# informe a primeira nota: 7
# informe a segunda nota: 8
# informe a terceira nota9
# media:  8.0

# %%
#Tarefa 7
nota1 = float(input("Informe a primeira nota: "))
peso1 = float(input("Informe o peso da primeira nota: "))
nota2 = float(input("Informe a segunda nota: "))
peso2 = float(input("Informe o peso da segunda nota: "))
nota3 = float(input("Informe a terceira nota: "))
peso3 = float(input("Informe o peso da terceira nota: "))

media_ponderada = (nota1 * peso1 + nota2 * peso2 + nota3 * peso3) / (peso1 + peso2 + peso3)

print(f"A média ponderada é: {media_ponderada}")

# %%
#Tarefa 8
numero = input("Informe um número: ")
soma_digitos = sum(int(digito) for digito in numero)
print(f"A soma dos dígitos é: {soma_digitos}")

# %%
#Tarefa 9
palavra = input("Informe uma palavra: ")
palavra_invertida = palavra[::-1]
print(f"A palavra invertida é: {palavra_invertida}")
